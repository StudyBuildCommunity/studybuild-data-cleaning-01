# %%
# Project 01
## Data Cleaning on an E-commerce Dataset

Author: Ali Khanbeigi

Objective:
Cleaning and preparing a raw e-commerce dataset for future analysis.
# Out:
#   Cell In[2], line 4
#     Author: Ali Khanbeigi
#                 ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df = pd.read_excel("D:\projects\project-01-data-cleaning\data\First Dataset.xlsx")

# %%
df.head()
# Out:
#    customer_id first_name gender   age     city  province signup_date  \
# 0         1001       Reza      F  19.0    Karaj    Alborz  2025-02-19
# 1         1002       Sina      M  53.0   Tehran    Tehran  2022-08-19
# 2         1003      Parsa      F  31.0   Shiraz      Fars  2023-06-20
# 3         1004       Sina      F  58.0  Mashhad  Khorasan  2021-11-08
# 4         1005      Kimia      M  28.0  Isfahan   Isfahan  2021-10-21
#
#   membership_tier  purchase_count  avg_order_value  total_spending  \
# 0             VIP              17           121.53         2066.01
# 1            Gold              12           326.47         3917.64
# 2            Gold              21            59.46         1248.66
# 3            Gold              23           266.15         6121.45
# 4          Silver              23           169.54         3899.42
#
#    last_purchase_days payment_method   device discount_used  returned_items  \
# ...

# %%
df.shape
# Out:
# (61, 17)

# %%
df.columns
# Out:
# Index(['customer_id', 'first_name', 'gender', 'age', 'city', 'province',
#        'signup_date', 'membership_tier', 'purchase_count', 'avg_order_value',
#        'total_spending', 'last_purchase_days', 'payment_method', 'device',
#        'discount_used', 'returned_items', 'satisfaction_score'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         61 non-null     int64
#  1   first_name          61 non-null     object
#  2   gender              61 non-null     object
#  3   age                 60 non-null     float64
#  4   city                61 non-null     object
#  5   province            61 non-null     object
#  6   signup_date         61 non-null     object
#  7   membership_tier     61 non-null     object
#  8   purchase_count      61 non-null     int64
#  9   avg_order_value     61 non-null     float64
#  10  total_spending      60 non-null     float64
#  11  last_purchase_days  61 non-null     int64
#  12  payment_method      61 non-null     object
#  13  device              61 non-null     object
#  14  discount_used       61 non-null     object
# ...

# %%
df.describe()
# Out:
#        customer_id         age  purchase_count  avg_order_value  \
# count    61.000000   60.000000       61.000000        61.000000
# mean   1030.229508   45.200000       17.606557       211.435738
# std      17.446483   19.167239       10.214824       130.113726
# min    1001.000000   19.000000        0.000000        27.630000
# 25%    1015.000000   31.750000       11.000000       108.190000
# 50%    1030.000000   45.000000       17.000000       161.330000
# 75%    1045.000000   58.000000       26.000000       323.320000
# max    1060.000000  145.000000       35.000000       449.810000
#
#        total_spending  last_purchase_days  returned_items  satisfaction_score
# count       60.000000           61.000000       61.000000            61.00000
# mean      3749.667333          196.934426        4.196721             3.00000
# std       4262.248522           97.892436        2.663454             1.42595
# min          0.000000            3.000000        0.000000             1.00000
# ...

# %%
df.describe(include='object')
# Out:
#        first_name gender    city         province signup_date membership_tier  \
# count          61     61      61               61          61              61
# unique         12      2       8                8          58               4
# top          Reza      F  Tabriz  East Azerbaijan  2021-11-08            Gold
# freq            8     35      13               13           2              19
#
#        payment_method   device discount_used
# count              61       61            61
# unique              3        3             2
# top     Online Wallet  Android            No
# freq               23       23            35

# %%
# missing value detection
df.isnull().sum()
# Out:
# customer_id           0
# first_name            0
# gender                0
# age                   1
# city                  0
# province              0
# signup_date           0
# membership_tier       0
# purchase_count        0
# avg_order_value       0
# total_spending        1
# last_purchase_days    0
# payment_method        0
# device                0
# discount_used         0
# returned_items        0
# satisfaction_score    0
# dtype: int64

# %%
# % Missing Value
(df.isnull().sum() / len(df)) * 100
# Out:
# customer_id           0.000000
# first_name            0.000000
# gender                0.000000
# age                   1.666667
# city                  0.000000
# province              0.000000
# signup_date           0.000000
# membership_tier       0.000000
# purchase_count        0.000000
# avg_order_value       0.000000
# total_spending        1.666667
# last_purchase_days    0.000000
# payment_method        0.000000
# device                0.000000
# discount_used         0.000000
# returned_items        0.000000
# satisfaction_score    0.000000
# dtype: float64

# %%
# checking duplicated records 
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# show duplicated records
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [customer_id, first_name, gender, age, city, province, signup_date, membership_tier, purchase_count, avg_order_value, total_spending, last_purchase_days, payment_method, device, discount_used, returned_items, satisfaction_score]
# Index: []

# %%
df[df.isnull().any(axis=1)]
# Out:
#     customer_id first_name gender   age     city province signup_date  \
# 19         1020      Kimia      M   NaN  Isfahan  Isfahan  2024-06-25
# 39         1040       Amir      F  65.0   Tehran   Tehran  2021-11-02
#
#    membership_tier  purchase_count  avg_order_value  total_spending  \
# 19          Bronze              16           187.17         2994.72
# 39          Bronze              34            37.66             NaN
#
#     last_purchase_days payment_method   device discount_used  returned_items  \
# 19                   4           Cash      Web           Yes               1
# 39                 126           Card  Android           Yes               3
#
#     satisfaction_score
# 19                   5
# 39                   2

# %%
df[df.duplicated(keep=False)]
# Out:
#     customer_id first_name gender   age    city         province signup_date  \
# 13         1014       Reza      M  35.0  Tabriz  East Azerbaijan  2022-08-26
# 60         1014       Reza      M  35.0  Tabriz  East Azerbaijan  2022-08-26
#
#    membership_tier  purchase_count  avg_order_value  total_spending  \
# 13             VIP              31           108.19         3353.89
# 60             VIP              31           108.19         3353.89
#
#     last_purchase_days payment_method   device discount_used  returned_items  \
# 13                  97           Card  Android            No               5
# 60                  97           Card  Android            No               5
#
#     satisfaction_score
# 13                   4
# 60                   4

# %%
# removing duplicated records
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# filling missing value of age by median
df["age"] = df["age"].fillna(df["age"].median())

# %%
# filling missing  value of total_spending
df["total_spending"] = df["total_spending"].fillna(
    df["purchase_count"] * df["avg_order_value"]
)

# %%
df.isnull().sum()
# Out:
# customer_id           0
# first_name            0
# gender                0
# age                   0
# city                  0
# province              0
# signup_date           0
# membership_tier       0
# purchase_count        0
# avg_order_value       0
# total_spending        0
# last_purchase_days    0
# payment_method        0
# device                0
# discount_used         0
# returned_items        0
# satisfaction_score    0
# dtype: int64

# %%
#checking outlier
df[df["age"] > 100]
# Out:
# Empty DataFrame
# Columns: [customer_id, first_name, gender, age, city, province, signup_date, membership_tier, purchase_count, avg_order_value, total_spending, last_purchase_days, payment_method, device, discount_used, returned_items, satisfaction_score]
# Index: []

# %%
# drop value of outlier
df.loc[df["age"] > 100, "age"] = np.nan

# %%
df["age"] = df["age"].fillna(df["age"].median())

# %%
df[df["customer_id"]==1010]
# Out:
#    customer_id first_name gender   age   city province signup_date  \
# 9         1010      Arash      F  45.0  Karaj   Alborz  2022-06-25
#
#   membership_tier  purchase_count  avg_order_value  total_spending  \
# 9          Silver              19           381.13         7241.47
#
#    last_purchase_days payment_method   device discount_used  returned_items  \
# 9                 276  Online Wallet  Android            No               7
#
#    satisfaction_score
# 9                   1

# %%
df[df["purchase_count"] == 0]
# Out:
#     customer_id first_name gender   age   city   province signup_date  \
# 23         1024       Sina      F  53.0  Ahvaz  Khuzestan  2025-01-27
#
#    membership_tier  purchase_count  avg_order_value  total_spending  \
# 23            Gold               0            63.67             0.0
#
#     last_purchase_days payment_method   device discount_used  returned_items  \
# 23                 298  Online Wallet  Android            No               2
#
#     satisfaction_score
# 23                   1

# %%
df[
    (df["purchase_count"] == 0) &
    (df["avg_order_value"] > 0)
]
# Out:
#     customer_id first_name gender   age   city   province signup_date  \
# 23         1024       Sina      F  53.0  Ahvaz  Khuzestan  2025-01-27
#
#    membership_tier  purchase_count  avg_order_value  total_spending  \
# 23            Gold               0            63.67             0.0
#
#     last_purchase_days payment_method   device discount_used  returned_items  \
# 23                 298  Online Wallet  Android            No               2
#
#     satisfaction_score
# 23                   1

# %%
df[df["total_spending"] == 0]
# Out:
#     customer_id first_name gender   age   city   province signup_date  \
# 23         1024       Sina      F  53.0  Ahvaz  Khuzestan  2025-01-27
#
#    membership_tier  purchase_count  avg_order_value  total_spending  \
# 23            Gold               0            63.67             0.0
#
#     last_purchase_days payment_method   device discount_used  returned_items  \
# 23                 298  Online Wallet  Android            No               2
#
#     satisfaction_score
# 23                   1

# %%
df[
    (df["satisfaction_score"] < 1) |
    (df["satisfaction_score"] > 5)
]
# Out:
# Empty DataFrame
# Columns: [customer_id, first_name, gender, age, city, province, signup_date, membership_tier, purchase_count, avg_order_value, total_spending, last_purchase_days, payment_method, device, discount_used, returned_items, satisfaction_score]
# Index: []

# %%
df["gender"].value_counts()
# Out:
# gender
# F    35
# M    25
# Name: count, dtype: int64

# %%
df["city"].unique()
# Out:
# array(['Karaj', 'Tehran', 'Shiraz', 'Mashhad', 'Isfahan', 'Rasht',
#        'Tabriz', 'Ahvaz'], dtype=object)

# %%
df["province"].unique()
# Out:
# array(['Alborz', 'Tehran', 'Fars', 'Khorasan', 'Isfahan', 'Gilan',
#        'East Azerbaijan', 'Khuzestan'], dtype=object)

# %%
df["membership_tier"].unique()
# Out:
# array(['VIP', 'Gold', 'Silver', 'Bronze'], dtype=object)

# %%
df["payment_method"].unique()
# Out:
# array(['Card', 'Online Wallet', 'Cash'], dtype=object)

# %%
df["device"].value_counts()
# Out:
# device
# Android    22
# Web        20
# iPhone     18
# Name: count, dtype: int64

# %%
df.groupby(["first_name", "gender"]).size().sort_index()
# Out:
# first_name  gender
# Ali         F         5
#             M         1
# Amir        F         4
#             M         2
# Arash       F         2
#             M         2
# Kimia       F         2
#             M         5
# Maryam      F         1
#             M         3
# Mina        F         1
#             M         2
# Neda        F         6
#             M         2
# Parsa       F         3
#             M         1
# Reza        F         5
#             M         2
# Sara        F         1
# Sina        F         5
#             M         3
# Zahra       M         2
# dtype: int64

# %%
male_names = [
    "Reza",
    "Ali",
    "Amir",
    "Sina",
    "Arash",
    "Parsa"
]

df.loc[df["first_name"].isin(male_names), "gender"] = "M"

# %%
female_names = [
    "Sara",
    "Maryam",
    "Kimia",
    "Mina",
    "Zahra",
    "Neda"
]

df.loc[df["first_name"].isin(female_names), "gender"] = "F"

# %%
df.groupby(["first_name", "gender"]).size().sort_index()
# Out:
# first_name  gender
# Ali         M         6
# Amir        M         6
# Arash       M         4
# Kimia       F         7
# Maryam      F         4
# Mina        F         3
# Neda        F         8
# Parsa       M         4
# Reza        M         7
# Sara        F         1
# Sina        M         8
# Zahra       F         2
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 60 entries, 0 to 59
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         60 non-null     int64
#  1   first_name          60 non-null     object
#  2   gender              60 non-null     object
#  3   age                 60 non-null     float64
#  4   city                60 non-null     object
#  5   province            60 non-null     object
#  6   signup_date         60 non-null     object
#  7   membership_tier     60 non-null     object
#  8   purchase_count      60 non-null     int64
#  9   avg_order_value     60 non-null     float64
#  10  total_spending      60 non-null     float64
#  11  last_purchase_days  60 non-null     int64
#  12  payment_method      60 non-null     object
#  13  device              60 non-null     object
#  14  discount_used       60 non-null     object
# ...

# %%
df.isnull().sum()
# Out:
# customer_id           0
# first_name            0
# gender                0
# age                   0
# city                  0
# province              0
# signup_date           0
# membership_tier       0
# purchase_count        0
# avg_order_value       0
# total_spending        0
# last_purchase_days    0
# payment_method        0
# device                0
# discount_used         0
# returned_items        0
# satisfaction_score    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#        customer_id        age  purchase_count  avg_order_value  \
# count    60.000000  60.000000       60.000000        60.000000
# mean   1030.500000  43.700000       17.383333       213.156500
# std      17.464249  13.946994       10.149880       130.509923
# min    1001.000000  19.000000        0.000000        27.630000
# 25%    1015.750000  31.750000       10.750000       108.137500
# 50%    1030.500000  45.000000       17.000000       165.435000
# 75%    1045.250000  58.000000       24.500000       324.107500
# max    1060.000000  65.000000       35.000000       449.810000
#
#        total_spending  last_purchase_days  returned_items  satisfaction_score
# count       60.000000           60.000000       60.000000           60.000000
# mean      3715.109833          198.600000        4.183333            2.983333
# std       4273.901437           97.843043        2.683861            1.431979
# min          0.000000            3.000000        0.000000            1.000000
# ...

# %%
df.to_excel("cleaned_dataset.xlsx", index=False)

# %%
## Final Summary

### Data Cleaning Tasks Performed

- Removed duplicate records.
- Handled missing values in age using the median.
- Recalculated missing values in total_spending.
- Corrected invalid age values (>100).
- Reviewed inconsistent records.
- Standardized categorical values.
- Corrected intentionally incorrect gender values for educational purposes.
- Exported the cleaned dataset.
