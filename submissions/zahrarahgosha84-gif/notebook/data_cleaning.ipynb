# %% [markdown]
# # This is a sample Jupyter Notebook
#
# Below is an example of a code cell.
# Put your cursor into the cell and press Shift+Enter to execute it and select the next one, or click 'Run Cell' button.
#
# Press Double Shift to search everywhere for classes, files, tool windows, actions, and settings.
#
# To learn more about Jupyter Notebooks in PyCharm, see [help](https://www.jetbrains.com/help/pycharm/ipython-notebook-support.html).
# For an overview of PyCharm, go to Help -> Learn IDE features or refer to [our documentation](https://www.jetbrains.com/help/pycharm/getting-started.html).

# %%
import pandas as pd

df = pd.read_excel("data/First Dataset.xlsx")
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[25], line 3
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_excel("data/First Dataset.xlsx")
#       4 print(df.head())
#
# File ~\PycharmProjects\JupyterProject6\.venv\Lib\site-packages\pandas\io\excel\_base.py:481, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     479 if not isinstance(io, ExcelFile):
#     480     should_close = True
# --> 481     io = ExcelFile(
#     482         io,
#     483         storage_options=storage_options,
#     484         engine=engine,
#     485         engine_kwargs=engine_kwargs,
#     486     )
# ...

# %%
import pandas as pd

df = pd.read_excel("First Dataset.xlsx")
print(df.head())
# Out:
#    customer_id first_name gender   age     city  province signup_date  \
# 0         1001       Reza      F  19.0    Karaj    Alborz  2025-02-19
# 1         1002       Sina      M  53.0   Tehran    Tehran  2022-08-19
# 2         1003      Parsa      F  31.0   Shiraz      Fars  2023-06-20
# 3         1004       Sina      F  58.0  Mashhad  Khorasan  2021-11-08
# 4         1005      Kimia      M  28.0  Isfahan   Isfahan  2021-10-21
#
#   membership_tier  purchase_count  avg_order_value  total_spending  \
# 0             VIP              17           121.53         2066.01
# 1            Gold              12           326.47         3917.64
# 2            Gold              21            59.46         1248.66
# 3            Gold              23           266.15         6121.45
# 4          Silver              23           169.54         3899.42
#
#    last_purchase_days payment_method   device discount_used  returned_items  \
# ...

# %%
df = df.dropna(subset=['age'])

# %%
df = df.drop(df[df['age']==145].index)

# %%
df=df.drop_duplicates(subset=['customer_id'])

# %%
gender_map={
'Ali':'M',
'Amir' : 'M',
'Arash': 'M',
'Kimia' :'F',
'Maryam' : 'F',
'Mina' :'F',
'Neda':'F',
'Parsa': 'M',
'Reza' :'M',
'Sara':'F',
'Sina' : 'M',
'Zahra':'F'}

# %%
df['gender'] = df['first_name'].map(gender_map)

# %%
print(df)
# Out:
#     customer_id first_name gender   age     city         province signup_date  \
# 0          1001       Reza      M  19.0    Karaj           Alborz  2025-02-19
# 1          1002       Sina      M  53.0   Tehran           Tehran  2022-08-19
# 2          1003      Parsa      M  31.0   Shiraz             Fars  2023-06-20
# 3          1004       Sina      M  58.0  Mashhad         Khorasan  2021-11-08
# 4          1005      Kimia      F  28.0  Isfahan          Isfahan  2021-10-21
# 5          1006       Amir      M  58.0  Mashhad         Khorasan  2022-01-26
# 6          1007       Reza      M  43.0    Rasht            Gilan  2025-09-09
# 7          1008       Reza      M  23.0    Rasht            Gilan  2024-10-03
# 8          1009      Kimia      F  61.0    Karaj           Alborz  2021-05-14
# 10         1011       Neda      F  41.0    Karaj           Alborz  2021-12-16
# 11         1012      Arash      M  51.0  Mashhad         Khorasan  2023-07-22
# ...

# %%
df.loc[df['customer_id']==1024,'avg_order_value']=0

# %%
print(df[df['customer_id']==1024])
# Out:
#     customer_id first_name gender   age   city   province signup_date  \
# 23         1024       Sina      M  53.0  Ahvaz  Khuzestan  2025-01-27
#
#    membership_tier  purchase_count  avg_order_value  total_spending  \
# 23            Gold               0              0.0             0.0
#
#     last_purchase_days payment_method   device discount_used  returned_items  \
# 23                 298  Online Wallet  Android            No               2
#
#     satisfaction_score
# 23                   1

# %%
df['signup_date'] = pd.to_datetime(df['signup_date'])

# %%
df['signup_date'].dtype
# Out:
# dtype('<M8[us]')

# %%
df = df.drop(df[df['customer_id']==1030].index)

# %%
df[df['customer_id']==1030]
# Out:
# Empty DataFrame
# Columns: [customer_id, first_name, gender, age, city, province, signup_date, membership_tier, purchase_count, avg_order_value, total_spending, last_purchase_days, payment_method, device, discount_used, returned_items, satisfaction_score]
# Index: []

# %%
print(df)
# Out:
#     customer_id first_name gender   age     city         province signup_date  \
# 0          1001       Reza      M  19.0    Karaj           Alborz  2025-02-19
# 1          1002       Sina      M  53.0   Tehran           Tehran  2022-08-19
# 2          1003      Parsa      M  31.0   Shiraz             Fars  2023-06-20
# 3          1004       Sina      M  58.0  Mashhad         Khorasan  2021-11-08
# 4          1005      Kimia      F  28.0  Isfahan          Isfahan  2021-10-21
# 5          1006       Amir      M  58.0  Mashhad         Khorasan  2022-01-26
# 6          1007       Reza      M  43.0    Rasht            Gilan  2025-09-09
# 7          1008       Reza      M  23.0    Rasht            Gilan  2024-10-03
# 8          1009      Kimia      F  61.0    Karaj           Alborz  2021-05-14
# 10         1011       Neda      F  41.0    Karaj           Alborz  2021-12-16
# 11         1012      Arash      M  51.0  Mashhad         Khorasan  2023-07-22
# ...

# %%
print(df.shape)
print(df.isnull().sum())
print(df.duplicated().sum())
# Out:
# (57, 17)
# customer_id           0
# first_name            0
# gender                0
# age                   0
# city                  0
# province              0
# signup_date           0
# membership_tier       0
# purchase_count        0
# avg_order_value       0
# total_spending        1
# last_purchase_days    0
# payment_method        0
# device                0
# discount_used         0
# returned_items        0
# satisfaction_score    0
# dtype: int64
# 0

# %%
df = df.dropna(subset=['total_spending'])

# %%
print(df.shape)
print(df.isnull().sum())
# Out:
# (56, 17)
# customer_id           0
# first_name            0
# gender                0
# age                   0
# city                  0
# province              0
# signup_date           0
# membership_tier       0
# purchase_count        0
# avg_order_value       0
# total_spending        0
# last_purchase_days    0
# payment_method        0
# device                0
# discount_used         0
# returned_items        0
# satisfaction_score    0
# dtype: int64

# %%
df.to_excel('cleaned_dataset.xlsx', index=False)
