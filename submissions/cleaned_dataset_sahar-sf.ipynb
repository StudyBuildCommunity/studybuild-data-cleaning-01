# %%
import pandas as pd

# %%
df=pd.read_excel(r"C:/Users/admin/Desktop/project/FirstDataset.xlsx")

# %%
df.head() #shows first 5 raws
# Out:
#    customer_id first_name gender   age     city  province signup_date  \
# 0         1001       Reza      F  19.0    Karaj    Alborz  2025-02-19
# 1         1002       Sina      M  53.0   Tehran    Tehran  2022-08-19
# 2         1003      Parsa      F  31.0   Shiraz      Fars  2023-06-20
# 3         1004       Sina      F  58.0  Mashhad  Khorasan  2021-11-08
# 4         1005      Kimia      M  28.0  Isfahan   Isfahan  2021-10-21
#
#   membership_tier  purchase_count  avg_order_value  total_spending  \
# 0             VIP              17           121.53         2066.01
# 1            Gold              12           326.47         3917.64
# 2            Gold              21            59.46         1248.66
# 3            Gold              23           266.15         6121.45
# 4          Silver              23           169.54         3899.42
#
#    last_purchase_days payment_method   device discount_used  returned_items  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         61 non-null     int64
#  1   first_name          61 non-null     object
#  2   gender              61 non-null     object
#  3   age                 60 non-null     float64
#  4   city                61 non-null     object
#  5   province            61 non-null     object
#  6   signup_date         61 non-null     object
#  7   membership_tier     61 non-null     object
#  8   purchase_count      61 non-null     int64
#  9   avg_order_value     61 non-null     float64
#  10  total_spending      60 non-null     float64
#  11  last_purchase_days  61 non-null     int64
#  12  payment_method      61 non-null     object
#  13  device              61 non-null     object
#  14  discount_used       61 non-null     object
# ...

# %%
df.shape #
# Out:
# (61, 17)

# %%
df.columns
# Out:
# Index(['customer_id', 'first_name', 'gender', 'age', 'city', 'province',
#        'signup_date', 'membership_tier', 'purchase_count', 'avg_order_value',
#        'total_spending', 'last_purchase_days', 'payment_method', 'device',
#        'discount_used', 'returned_items', 'satisfaction_score'],
#       dtype='object')

# %%
df.describe()
# Out:
#        customer_id         age  purchase_count  avg_order_value  \
# count    61.000000   60.000000       61.000000        61.000000
# mean   1030.229508   45.200000       17.606557       211.435738
# std      17.446483   19.167239       10.214824       130.113726
# min    1001.000000   19.000000        0.000000        27.630000
# 25%    1015.000000   31.750000       11.000000       108.190000
# 50%    1030.000000   45.000000       17.000000       161.330000
# 75%    1045.000000   58.000000       26.000000       323.320000
# max    1060.000000  145.000000       35.000000       449.810000
#
#        total_spending  last_purchase_days  returned_items  satisfaction_score
# count       60.000000           61.000000       61.000000            61.00000
# mean      3749.667333          196.934426        4.196721             3.00000
# std       4262.248522           97.892436        2.663454             1.42595
# min          0.000000            3.000000        0.000000             1.00000
# ...

# %%
df["signup_date"]= pd.to_datetime(df["signup_date"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         61 non-null     int64
#  1   first_name          61 non-null     object
#  2   gender              61 non-null     object
#  3   age                 60 non-null     float64
#  4   city                61 non-null     object
#  5   province            61 non-null     object
#  6   signup_date         61 non-null     datetime64[ns]
#  7   membership_tier     61 non-null     object
#  8   purchase_count      61 non-null     int64
#  9   avg_order_value     61 non-null     float64
#  10  total_spending      60 non-null     float64
#  11  last_purchase_days  61 non-null     int64
#  12  payment_method      61 non-null     object
#  13  device              61 non-null     object
#  14  discount_used       61 non-null     object
# ...

# %%
df.isnull().sum()
# Out:
# customer_id           0
# first_name            0
# gender                0
# age                   1
# city                  0
# province              0
# signup_date           0
# membership_tier       0
# purchase_count        0
# avg_order_value       0
# total_spending        1
# last_purchase_days    0
# payment_method        0
# device                0
# discount_used         0
# returned_items        0
# satisfaction_score    0
# dtype: int64

# %%
df[df['age'].isnull()]
# Out:
#     customer_id first_name gender  age     city province signup_date  \
# 19         1020      Kimia      M  NaN  Isfahan  Isfahan  2024-06-25
#
#    membership_tier  purchase_count  avg_order_value  total_spending  \
# 19          Bronze              16           187.17         2994.72
#
#     last_purchase_days payment_method device discount_used  returned_items  \
# 19                   4           Cash    Web           Yes               1
#
#     satisfaction_score
# 19                   5

# %%
df[df["total_spending"].isnull()]
# Out:
#     customer_id first_name gender   age    city province signup_date  \
# 39         1040       Amir      F  65.0  Tehran   Tehran  2021-11-02
#
#    membership_tier  purchase_count  avg_order_value  total_spending  \
# 39          Bronze              34            37.66             NaN
#
#     last_purchase_days payment_method   device discount_used  returned_items  \
# 39                 126           Card  Android           Yes               3
#
#     satisfaction_score
# 39                   2

# %%
df.loc[df["total_spending"].isnull(),"total_spending"]=(df.loc[df["total_spending"].isnull(),"avg_order_value"]*df.loc[df["total_spending"].isnull(),"purchase_count"])

# %%
df.isnull().sum()
# Out:
# customer_id           0
# first_name            0
# gender                0
# age                   1
# city                  0
# province              0
# signup_date           0
# membership_tier       0
# purchase_count        0
# avg_order_value       0
# total_spending        0
# last_purchase_days    0
# payment_method        0
# device                0
# discount_used         0
# returned_items        0
# satisfaction_score    0
# dtype: int64

# %%
df.loc[df["first_name"] == "Kimia","age"] = df["age"].median()

# %%
df.isnull().sum()
# Out:
# customer_id           0
# first_name            0
# gender                0
# age                   0
# city                  0
# province              0
# signup_date           0
# membership_tier       0
# purchase_count        0
# avg_order_value       0
# total_spending        0
# last_purchase_days    0
# payment_method        0
# device                0
# discount_used         0
# returned_items        0
# satisfaction_score    0
# dtype: int64

# %%
df["age"].unique()
# Out:
# array([ 19.,  53.,  31.,  58.,  45.,  43.,  23., 145.,  41.,  51.,  39.,
#         35.,  49.,  30.,  22.,  50.,  60.,  25.,  34.,  37.,  63.,  26.,
#         42.,  47.,  65.,  64.,  54.,  32.,  48.,  59.,  62.,  57.])

# %%
df["age"]=df["age"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         61 non-null     int64
#  1   first_name          61 non-null     object
#  2   gender              61 non-null     object
#  3   age                 61 non-null     int64
#  4   city                61 non-null     object
#  5   province            61 non-null     object
#  6   signup_date         61 non-null     datetime64[ns]
#  7   membership_tier     61 non-null     object
#  8   purchase_count      61 non-null     int64
#  9   avg_order_value     61 non-null     float64
#  10  total_spending      61 non-null     float64
#  11  last_purchase_days  61 non-null     int64
#  12  payment_method      61 non-null     object
#  13  device              61 non-null     object
#  14  discount_used       61 non-null     object
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 56    False
# 57    False
# 58    False
# 59    False
# 60     True
# Length: 61, dtype: bool

# %%
df=df.drop_duplicates()

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# 54    False
# 55    False
# 56    False
# 57    False
# 58    False
# 59    False
# dtype: bool

# %%
df.dtypes
# Out:
# customer_id                    int64
# first_name                    object
# gender                        object
# age                            int64
# city                          object
# province                      object
# signup_date           datetime64[ns]
# membership_tier               object
# purchase_count                 int64
# avg_order_value              float64
# total_spending               float64
# last_purchase_days             int64
# payment_method                object
# device                        object
# discount_used                 object
# returned_items                 int64
# satisfaction_score             int64
# dtype: object

# %%
num_col_list = ['customer_id','age','purchase_count','avg_order_value','total_spending','last_purchase_days','returned_items','satisfaction_score'] #The list includes numeric columns of table


for colname in num_col_list:  #check if numbers are negaive
    col = df[f'{colname}']
    for i in col:
        if i<0:
            print(i)

# %%
import matplotlib.pyplot as plt

df.boxplot (column='age')
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df['first_name']=df['first_name'].str.strip()

# %%
df['gender']=df['gender'].str.strip()

# %%
df['city']=df['city'].str.strip()

# %%
# replace 145 with median in age column
df.loc[df['age'] == 145,'age'] = df['age'].median()

# %%
df["age"]
# Out:
# 0     19
# 1     53
# 2     31
# 3     58
# 4     45
# 5     58
# 6     43
# 7     23
# 8     45
# 9     45
# 10    41
# 11    51
# 12    39
# 13    35
# 14    45
# 15    45
# 16    49
# 17    30
# 18    22
# 19    45
# 20    50
# 21    60
# 22    50
# 23    53
# 24    41
# 25    19
# 26    45
# 27    25
# 28    34
# 29    60
# 30    37
# 31    23
# 32    63
# 33    25
# 34    58
# 35    26
# 36    42
# 37    45
# 38    47
# 39    65
# 40    60
# 41    43
# 42    45
# 43    64
# 44    54
# 45    23
# 46    37
# 47    25
# 48    32
# 49    48
# 50    23
# 51    31
# 52    32
# 53    59
# 54    62
# 55    45
# 56    58
# 57    47
# 58    57
# 59    63
# Name: age, dtype: int64

# %%
df
# Out:
#     customer_id first_name gender  age     city         province signup_date  \
# 0          1001       Reza      F   19    Karaj           Alborz  2025-02-19
# 1          1002       Sina      M   53   Tehran           Tehran  2022-08-19
# 2          1003      Parsa      F   31   Shiraz             Fars  2023-06-20
# 3          1004       Sina      F   58  Mashhad         Khorasan  2021-11-08
# 4          1005      Kimia      M   45  Isfahan          Isfahan  2021-10-21
# 5          1006       Amir      F   58  Mashhad         Khorasan  2022-01-26
# 6          1007       Reza      F   43    Rasht            Gilan  2025-09-09
# 7          1008       Reza      F   23    Rasht            Gilan  2024-10-03
# 8          1009      Kimia      M   45    Karaj           Alborz  2021-05-14
# 9          1010      Arash      F   45    Karaj           Alborz  2022-06-25
# 10         1011       Neda      F   41    Karaj           Alborz  2021-12-16
# ...

# %%
A=list(df['first_name'].unique())
A
# Out:
# ['Reza',
#  'Sina',
#  'Parsa',
#  'Kimia',
#  'Amir',
#  'Arash',
#  'Neda',
#  'Ali',
#  'Mina',
#  'Zahra',
#  'Maryam',
#  'Sara']

# %%
gender_corection={
    'Reza':'M',
    'Sina':'M',
    'Parsa':'M',
    'Kimia':'F',
    'Amir':'M',
    'Arash':'M',
    'Neda':'F',
    'Ali':'M',
    'Mina':'F',
    'Zahra':'F',
    'Maryam':'F',
    'Sara':'F'}

# %%
df['gender'] = df['first_name'].map(gender_corection).fillna(df['gender'])

# %%
df
# Out:
#     customer_id first_name gender  age     city         province signup_date  \
# 0          1001       Reza      M   19    Karaj           Alborz  2025-02-19
# 1          1002       Sina      M   53   Tehran           Tehran  2022-08-19
# 2          1003      Parsa      M   31   Shiraz             Fars  2023-06-20
# 3          1004       Sina      M   58  Mashhad         Khorasan  2021-11-08
# 4          1005      Kimia      F   45  Isfahan          Isfahan  2021-10-21
# 5          1006       Amir      M   58  Mashhad         Khorasan  2022-01-26
# 6          1007       Reza      M   43    Rasht            Gilan  2025-09-09
# 7          1008       Reza      M   23    Rasht            Gilan  2024-10-03
# 8          1009      Kimia      F   45    Karaj           Alborz  2021-05-14
# 9          1010      Arash      M   45    Karaj           Alborz  2022-06-25
# 10         1011       Neda      F   41    Karaj           Alborz  2021-12-16
# ...
