# %% [markdown]
# # Project 01: Data Cleaning on a Real E-commerce Dataset

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd

# %% [markdown]
# ## 2. Load Dataset

# %%
df = pd.read_excel("E:/.vscode/Study_build_p01/studybuild-data-cleaning-01/FirstDataset.xlsx")

# %% [markdown]
# ## 3. Initial Data Inspection

# %%
df.shape
# Out:
# (61, 17)

# %%
df.columns
# Out:
# Index(['customer_id', 'first_name', 'gender', 'age', 'city', 'province',
#        'signup_date', 'membership_tier', 'purchase_count', 'avg_order_value',
#        'total_spending', 'last_purchase_days', 'payment_method', 'device',
#        'discount_used', 'returned_items', 'satisfaction_score'],
#       dtype='object')

# %%
df
# Out:
#     customer_id first_name gender   age     city         province signup_date  \
# 0          1001       Reza      F  19.0    Karaj           Alborz  2025-02-19
# 1          1002       Sina      M  53.0   Tehran           Tehran  2022-08-19
# 2          1003      Parsa      F  31.0   Shiraz             Fars  2023-06-20
# 3          1004       Sina      F  58.0  Mashhad         Khorasan  2021-11-08
# 4          1005      Kimia      M  28.0  Isfahan          Isfahan  2021-10-21
# ..          ...        ...    ...   ...      ...              ...         ...
# 56         1057     Maryam      M  58.0    Ahvaz        Khuzestan  2024-06-11
# 57         1058       Amir      F  47.0   Tehran           Tehran  2024-09-27
# 58         1059        Ali      F  57.0  Isfahan          Isfahan  2023-09-05
# 59         1060        Ali      M  63.0   Tabriz  East Azerbaijan  2021-04-27
# 60         1014       Reza      M  35.0   Tabriz  East Azerbaijan  2022-08-26
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         61 non-null     int64
#  1   first_name          61 non-null     object
#  2   gender              61 non-null     object
#  3   age                 60 non-null     float64
#  4   city                61 non-null     object
#  5   province            61 non-null     object
#  6   signup_date         61 non-null     object
#  7   membership_tier     61 non-null     object
#  8   purchase_count      61 non-null     int64
#  9   avg_order_value     61 non-null     float64
#  10  total_spending      60 non-null     float64
#  11  last_purchase_days  61 non-null     int64
#  12  payment_method      61 non-null     object
#  13  device              61 non-null     object
#  14  discount_used       61 non-null     object
# ...

# %%
df.describe().transpose()
# Out:
#                     count         mean          std      min       25%  \
# customer_id          61.0  1030.229508    17.446483  1001.00  1015.000
# age                  60.0    45.200000    19.167239    19.00    31.750
# purchase_count       61.0    17.606557    10.214824     0.00    11.000
# avg_order_value      61.0   211.435738   130.113726    27.63   108.190
# total_spending       60.0  3749.667333  4262.248522     0.00  1167.035
# last_purchase_days   61.0   196.934426    97.892436     3.00   132.000
# returned_items       61.0     4.196721     2.663454     0.00     2.000
# satisfaction_score   61.0     3.000000     1.425950     1.00     2.000
#
#                          50%      75%       max
# customer_id         1030.000  1045.00   1060.00
# age                   45.000    58.00    145.00
# purchase_count        17.000    26.00     35.00
# avg_order_value      161.330   323.32    449.81
# total_spending      2188.865  4692.15  25000.00
# ...

# %% [markdown]
# ## 4. Detect Duplicate Records

# %%
df[df.duplicated()]
# Out:
#     customer_id first_name gender   age    city         province signup_date  \
# 60         1014       Reza      M  35.0  Tabriz  East Azerbaijan  2022-08-26
#
#    membership_tier  purchase_count  avg_order_value  total_spending  \
# 60             VIP              31           108.19         3353.89
#
#     last_purchase_days payment_method   device discount_used  returned_items  \
# 60                  97           Card  Android            No               5
#
#     satisfaction_score
# 60                   4

# %%
df = df.drop_duplicates()

# %% [markdown]
# ## 5. Handle Missing Values

# %%
df.isna().sum()
# Out:
# customer_id           0
# first_name            0
# gender                0
# age                   1
# city                  0
# province              0
# signup_date           0
# membership_tier       0
# purchase_count        0
# avg_order_value       0
# total_spending        1
# last_purchase_days    0
# payment_method        0
# device                0
# discount_used         0
# returned_items        0
# satisfaction_score    0
# dtype: int64

# %%
df[df["age"].isna()]
# Out:
#     customer_id first_name gender  age     city province signup_date  \
# 19         1020      Kimia      M  NaN  Isfahan  Isfahan  2024-06-25
#
#    membership_tier  purchase_count  avg_order_value  total_spending  \
# 19          Bronze              16           187.17         2994.72
#
#     last_purchase_days payment_method device discount_used  returned_items  \
# 19                   4           Cash    Web           Yes               1
#
#     satisfaction_score
# 19                   5

# %%
df["age"] = df["age"].fillna(df["age"].median())

# %%
df[df["total_spending"].isna()]
# Out:
#     customer_id first_name gender   age    city province signup_date  \
# 39         1040       Amir      F  65.0  Tehran   Tehran  2021-11-02
#
#    membership_tier  purchase_count  avg_order_value  total_spending  \
# 39          Bronze              34            37.66             NaN
#
#     last_purchase_days payment_method   device discount_used  returned_items  \
# 39                 126           Card  Android           Yes               3
#
#     satisfaction_score
# 39                   2

# %%
df["total_spending"] = df["total_spending"].fillna(df["total_spending"].median())

# %%
df.isna().sum()
# Out:
# customer_id           0
# first_name            0
# gender                0
# age                   0
# city                  0
# province              0
# signup_date           0
# membership_tier       0
# purchase_count        0
# avg_order_value       0
# total_spending        0
# last_purchase_days    0
# payment_method        0
# device                0
# discount_used         0
# returned_items        0
# satisfaction_score    0
# dtype: int64

# %% [markdown]
# ## 6. Correct Data Types

# %%
df["signup_date"].dtype
# Out:
# dtype('O')

# %%
df["signup_date"] = pd.to_datetime(df["signup_date"])

# %%
df["signup_date"].dtype
# Out:
# dtype('<M8[ns]')

# %%
df["signup_date"].min()
# Out:
# Timestamp('2021-02-23 00:00:00')

# %%
df["signup_date"].max()
# Out:
# Timestamp('2025-09-09 00:00:00')

# %% [markdown]
# ## 7. Detect Invalid Values

# %%
df[df["age"]>100]
# Out:
#    customer_id first_name gender    age   city province signup_date  \
# 9         1010      Arash      F  145.0  Karaj   Alborz  2022-06-25
#
#   membership_tier  purchase_count  avg_order_value  total_spending  \
# 9          Silver              19           381.13         7241.47
#
#    last_purchase_days payment_method   device discount_used  returned_items  \
# 9                 276  Online Wallet  Android            No               7
#
#    satisfaction_score
# 9                   1

# %%
df["age"].median()
# Out:
# np.float64(45.0)

# %%
df.loc[df["age"]>100, "age"] = df["age"].median()

# %%
df[df["age"]>100]
# Out:
# Empty DataFrame
# Columns: [customer_id, first_name, gender, age, city, province, signup_date, membership_tier, purchase_count, avg_order_value, total_spending, last_purchase_days, payment_method, device, discount_used, returned_items, satisfaction_score]
# Index: []

# %% [markdown]
# ## 8. Detect Inconsistent Categorical Values

# %%
df["gender"].value_counts()
# Out:
# gender
# F    35
# M    25
# Name: count, dtype: int64

# %%
df["city"].value_counts()
# Out:
# city
# Tabriz     12
# Mashhad    11
# Ahvaz       8
# Karaj       7
# Shiraz      6
# Tehran      6
# Rasht       5
# Isfahan     5
# Name: count, dtype: int64

# %%
df[["province", "city"]]
# Out:
#            province     city
# 0            Alborz    Karaj
# 1            Tehran   Tehran
# 2              Fars   Shiraz
# 3          Khorasan  Mashhad
# 4           Isfahan  Isfahan
# 5          Khorasan  Mashhad
# 6             Gilan    Rasht
# 7             Gilan    Rasht
# 8            Alborz    Karaj
# 9            Alborz    Karaj
# 10           Alborz    Karaj
# 11         Khorasan  Mashhad
# 12           Alborz    Karaj
# 13  East Azerbaijan   Tabriz
# 14        Khuzestan    Ahvaz
# 15             Fars   Shiraz
# 16        Khuzestan    Ahvaz
# 17             Fars   Shiraz
# 18             Fars   Shiraz
# 19          Isfahan  Isfahan
# 20  East Azerbaijan   Tabriz
# 21         Khorasan  Mashhad
# 22         Khorasan  Mashhad
# 23        Khuzestan    Ahvaz
# 24         Khorasan  Mashhad
# 25        Khuzestan    Ahvaz
# 26          Isfahan  Isfahan
# 27           Tehran   Tehran
# 28  East Azerbaijan   Tabriz
# 29         Khorasan  Mashhad
# 30           Tehran   Tehran
# ...

# %%
df["membership_tier"].value_counts()
# Out:
# membership_tier
# Gold      19
# Bronze    18
# VIP       15
# Silver     8
# Name: count, dtype: int64

# %%
df["payment_method"].value_counts()
# Out:
# payment_method
# Online Wallet    23
# Cash             19
# Card             18
# Name: count, dtype: int64

# %%
df["device"].value_counts()
# Out:
# device
# Android    22
# Web        20
# iPhone     18
# Name: count, dtype: int64

# %%
df["discount_used"].value_counts()
# Out:
# discount_used
# No     34
# Yes    26
# Name: count, dtype: int64

# %%
df["satisfaction_score"].value_counts(sort=True)
# Out:
# satisfaction_score
# 2    16
# 4    13
# 5    12
# 1    11
# 3     8
# Name: count, dtype: int64

# %% [markdown]
# ## 9. Fix Gender Inconsistencies

# %%
df.groupby(["first_name"]).nunique()["gender"]
# Out:
# first_name
# Ali       2
# Amir      2
# Arash     2
# Kimia     2
# Maryam    2
# Mina      2
# Neda      2
# Parsa     2
# Reza      2
# Sara      1
# Sina      2
# Zahra     1
# Name: gender, dtype: int64

# %%
df[df["first_name"]=="Arash"]
# Out:
#     customer_id first_name gender   age     city         province signup_date  \
# 9          1010      Arash      F  45.0    Karaj           Alborz  2022-06-25
# 11         1012      Arash      F  51.0  Mashhad         Khorasan  2023-07-22
# 34         1035      Arash      M  58.0   Tabriz  East Azerbaijan  2022-05-15
# 46         1047      Arash      M  37.0   Tabriz  East Azerbaijan  2024-12-18
#
#    membership_tier  purchase_count  avg_order_value  total_spending  \
# 9           Silver              19           381.13         7241.47
# 11            Gold              27           434.50        11731.50
# 34          Bronze              17           348.13         5918.21
# 46            Gold              23           220.87         5080.01
#
#     last_purchase_days payment_method   device discount_used  returned_items  \
# 9                  276  Online Wallet  Android            No               7
# 11                 224  Online Wallet   iPhone           Yes               3
# ...

# %%
list(df.groupby(["first_name"])["gender"])
# Out:
# [(('Ali',),
#   17    F
#   22    F
#   28    F
#   48    F
#   58    F
#   59    M
#   Name: gender, dtype: object),
#  (('Amir',),
#   5     F
#   20    F
#   25    M
#   37    M
#   39    F
#   57    F
#   Name: gender, dtype: object),
#  (('Arash',),
#   9     F
#   11    F
#   34    M
#   46    M
#   Name: gender, dtype: object),
#  (('Kimia',),
#   4     M
#   8     M
#   14    F
#   19    M
#   26    F
#   42    M
#   55    M
#   Name: gender, dtype: object),
#  (('Maryam',),
#   33    M
#   44    M
#   45    F
#   56    M
#   Name: gender, dtype: object),
#  (('Mina',),
#   27    F
#   43    M
#   54    M
#   Name: gender, dtype: object),
#  (('Neda',),
#   10    F
#   12    F
#   15    F
#   18    M
#   24    F
#   31    F
#   32    F
#   40    M
#   Name: gender, dtype: object),
#  (('Parsa',),
#   2     F
#   16    F
#   38    M
#   50    F
#   Name: gender, dtype: object),
#  (('Reza',),
#   0     F
#   6     F
#   7     F
#   13    M
#   21    M
#   49    F
#   53    F
# ...

# %%
correct_gender = {
    "Ali"    : "M",
    "Amir"   : "M",
    "Arash"  : "M",
    "Kimia"  : "F",
    "Maryam" : "F",
    "Mina"   : "F",
    "Neda"   : "F",
    "Parsa"  : "M",
    "Reza"   : "M",
    "Sara"   : "F",
    "Sina"   : "M",
    "Zahra"  : "F" 
}
df["gender"] = df["first_name"].map(correct_gender)

# %%
df.groupby(["first_name"]).nunique()["gender"]
# Out:
# first_name
# Ali       1
# Amir      1
# Arash     1
# Kimia     1
# Maryam    1
# Mina      1
# Neda      1
# Parsa     1
# Reza      1
# Sara      1
# Sina      1
# Zahra     1
# Name: gender, dtype: int64

# %%
df.head()
# Out:
#    customer_id first_name gender   age     city  province signup_date  \
# 0         1001       Reza      M  19.0    Karaj    Alborz  2025-02-19
# 1         1002       Sina      M  53.0   Tehran    Tehran  2022-08-19
# 2         1003      Parsa      M  31.0   Shiraz      Fars  2023-06-20
# 3         1004       Sina      M  58.0  Mashhad  Khorasan  2021-11-08
# 4         1005      Kimia      F  28.0  Isfahan   Isfahan  2021-10-21
#
#   membership_tier  purchase_count  avg_order_value  total_spending  \
# 0             VIP              17           121.53         2066.01
# 1            Gold              12           326.47         3917.64
# 2            Gold              21            59.46         1248.66
# 3            Gold              23           266.15         6121.45
# 4          Silver              23           169.54         3899.42
#
#    last_purchase_days payment_method   device discount_used  returned_items  \
# ...

# %% [markdown]
# ## 10. Validate Business Rules

# %%
df[df["purchase_count"] < df["returned_items"]]
# Out:
#     customer_id first_name gender   age    city         province signup_date  \
# 7          1008       Reza      M  23.0   Rasht            Gilan  2024-10-03
# 14         1015      Kimia      F  47.0   Ahvaz        Khuzestan  2021-07-24
# 23         1024       Sina      M  53.0   Ahvaz        Khuzestan  2025-01-27
# 28         1029        Ali      M  34.0  Tabriz  East Azerbaijan  2023-07-03
# 36         1037      Zahra      F  42.0   Ahvaz        Khuzestan  2024-01-12
# 55         1056      Kimia      F  61.0  Tabriz  East Azerbaijan  2025-01-25
#
#    membership_tier  purchase_count  avg_order_value  total_spending  \
# 7              VIP               3           389.58         1168.74
# 14            Gold               3           307.91          923.73
# 23            Gold               0            63.67            0.00
# 28            Gold               2           323.32          646.64
# 36            Gold               1           387.68          387.68
# ...

# %%
df.loc[df["purchase_count"] < df["returned_items"], "returned_items"] = df["purchase_count"]

# %%
df[df["purchase_count"] < df["returned_items"]]
# Out:
# Empty DataFrame
# Columns: [customer_id, first_name, gender, age, city, province, signup_date, membership_tier, purchase_count, avg_order_value, total_spending, last_purchase_days, payment_method, device, discount_used, returned_items, satisfaction_score]
# Index: []

# %%
df[df["total_spending"] <= 0]
# Out:
#     customer_id first_name gender   age   city   province signup_date  \
# 23         1024       Sina      M  53.0  Ahvaz  Khuzestan  2025-01-27
#
#    membership_tier  purchase_count  avg_order_value  total_spending  \
# 23            Gold               0            63.67             0.0
#
#     last_purchase_days payment_method   device discount_used  returned_items  \
# 23                 298  Online Wallet  Android            No               0
#
#     satisfaction_score
# 23                   1

# %%
ts = round((df["purchase_count"] * df["avg_order_value"]), 2)
df[ts != df["total_spending"]]
# Out:
#     customer_id first_name gender   age     city  province signup_date  \
# 29         1030       Sina      M  60.0  Mashhad  Khorasan  2025-03-07
# 39         1040       Amir      M  65.0   Tehran    Tehran  2021-11-02
#
#    membership_tier  purchase_count  avg_order_value  total_spending  \
# 29             VIP              26           156.89        25000.00
# 39          Bronze              34            37.66         2140.38
#
#     last_purchase_days payment_method   device discount_used  returned_items  \
# 29                 340           Cash      Web           Yes               4
# 39                 126           Card  Android           Yes               3
#
#     satisfaction_score
# 29                   4
# 39                   2

# %%
ts.loc[29]
# Out:
# np.float64(4079.14)

# %%
ts.loc[39]
# Out:
# np.float64(1280.44)

# %% [markdown]
# ## 11.Save Cleaned Dataset

# %%
df.to_excel("../data/cleaned_dataset_maralfarahmandfar.xlsx", index=False)
